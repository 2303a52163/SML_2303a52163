# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a52163/SML_2303a52163/blob/main/SML3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#                   **STML ASSIGNMENT-3**
#
#
#
#    **Course Name:        Statistical Machine Learning**
#
#    **Resources:          Google Colab**
#
#    **Name:               U.Maheesh Varma**
#
#    **RollNo:             2303A52163**
#
#    **Batch:              34**

# %% [markdown]
# **1.Find out the maximum likelihood parameters values for** **california_housing [‘latiyude’,total_rooms’,’house_median_age’,**’**total_bedrooms’] data, each column individually.**

# %%
from numpy import sqrt,log,pi,exp
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('/content/housing.csv')
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
columns = ['latitude', 'total_rooms', 'housing_median_age', 'total_bedrooms'] # Define columns as a list
for column in columns:
  if column in dp.columns:
       stats = dp[column].agg(['mean', 'var'])
       print(f"Column: {column}")
       print(f"Mean (MLE): {stats['mean']}")
       print(f"Variance (MLE): {stats['var']}\n")
else:
    print(f"Warning: Column {column} not found in DataFrame.\n") #
# Out:
# Column: latitude
# Mean (MLE): 35.63186143410853
# Variance (MLE): 4.562292644202798
#
# Column: total_rooms
# Mean (MLE): 2635.7630813953488
# Variance (MLE): 4759445.105938661
#
# Column: housing_median_age
# Mean (MLE): 28.639486434108527
# Variance (MLE): 158.39626040778148
#
# Column: total_bedrooms
# Mean (MLE): 537.8705525375618
# Variance (MLE): 177565.3772812971
#
# ...

# %% [markdown]
# **2.Find log-likelihood values for 50, 75, and 80. For California_housing** **[‘latitude’] and find the Max likelihood values.**

# %%
def FindMLEAndLLv(x):
    m = dp['latitude'].mean()
    v = dp['latitude'].var()
    mle=(1/(sqrt(2*pi*v)))*(exp(-(x-m)**2/(2*v)))
    return mle , np.log(mle)
x_values = [50,75,80]
for x in x_values:
             mle,lle = FindMLEAndLLv(x)
             print(f"the max likelyhood value of {x} is : {mle}")
             print(f"the log-likelihood value of {x} is : {lle}")
             print("\n")
# Out:
# the max likelyhood value of 50 is : 2.7888287682024593e-11
# the log-likelihood value of 50 is : -24.302814311583585
#
#
# the max likelyhood value of 75 is : 3.1953586400568146e-75
# the log-likelihood value of 75 is : -171.53218264261452
#
#
# the max likelyhood value of 80 is : 3.775090060098623e-95
# the log-likelihood value of 80 is : -217.41715959503816

# %% [markdown]
# 3.**Estimate the density of each column of california_housing [‘latitude’,**
# **'total_rooms’,’house_median_age’,’total_bedrooms’] data, For the bins [5, 10,**
# **15, 20]**
# .**And write the observations.**

# %%
import numpy as np
from numpy import sqrt,log,pi,exp
import pandas as pd
import matplotlib.pyplot as plt
a1 = df['latitude']
a2 = df['total_rooms']
a3 = df['housing_median_age']
a4 = df['total_bedrooms']
def plot_density(data, num):
    plt.hist(data, bins=num, density=True, edgecolor='black', color='blue')
    plt.title('Density Histogram')
    plt.xlabel('Data Values')
    plt.ylabel('Density')
    plt.show()
bin_options = [5, 10, 15, 20]
for num in bin_options:
    print(f"Number of bins: {num}")
    print("latitude")
    print(plot_density(a1, num))
    print("total_rooms")
    print(plot_density(a2, num))
    print("housing_median_age")
    print(plot_density(a3, num))
    print("total_bedrooms")
    print(plot_density(a4, num))
# Out:
# Number of bins: 5
# latitude
# None
# total_rooms
# None
# housing_median_age
# None
# total_bedrooms
# None
# Number of bins: 10
# latitude
# None
# total_rooms
# None
# housing_median_age
# None
# total_bedrooms
# None
# Number of bins: 15
# latitude
# None
# total_rooms
# None
# housing_median_age
# None
# total_bedrooms
# None
# Number of bins: 20
# latitude
# None
# total_rooms
# None
# housing_median_age
# None
# total_bedrooms
# None
